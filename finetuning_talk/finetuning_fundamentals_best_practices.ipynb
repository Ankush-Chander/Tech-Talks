# %% [markdown]
# # Finetuning: Fundamentals and best practices

# %% [markdown]
# ## LLM overview
# What are LLMS?

# %% [markdown]
# ## Stages of LLM
# Pretraining
# Post training
# Instruction finetuning

# %% [markdown]
# ## Finetuning: overview?

# %% [markdown]
# ### When to finetune?

# %% [markdown]
# ### Reasons not to finetune?

# %% [markdown]
# ### Finetune vs RAG

# %% [markdown]
# ## Hardware estimation

# %% [markdown]
# ## Finetuning techniques

# %% [markdown]
# ### Quantization

# %% [markdown]
# ### Parameter efficient techniques
# Lora, QLora

# %% [markdown]
# # Demo 1: Fine tune a small huggingface model

# %% [markdown]
# # Demo 2: Fine tune an OpenAI LLM

# %% [markdown]
# # Demo 3: Fine tune an OpenSource LLM
