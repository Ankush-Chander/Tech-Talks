# %%
# install dependencies

# %% [markdown]
# # Set up model
#
#
# ```bash
# # download model from hub
# # get model from huggingface
#
# litgpt download meta-llama/Llama-2-7b-hf
# # # convert into lit-gpt format if not already
# litgpt convert_to_litgpt  checkpoints/meta-llama/Llama-2-7b-hf --model_name meta-llama/Llama-2-7b-hf
#
#
#
# ```

# %% [markdown]
# # Prepare the data
# # download dolly-2 dataset
# ```bash
# # download dataset in csv format from kaggle
# curl -L -o ./data/databricks-dolly-15k-dataset.zip  https://www.kaggle.com/api/v1/datasets/download/snehilsanyal/databricks-dolly-15k-datasets
# unzip -d ./data/ ./data/databricks-dolly-15k-dataset.zip
# # TODO: fix prepare_csv
# # figure out cloning using ssh-key other than home
# ```

# %%
# Finetune the model

# litgpt finetune checkpoints/meta-llama/Llama-2-7b-hf --out_dir out/finetune/lora
# will lead to OOM

# %% [markdown]
# # References
# 1. [Dolly dataset](https://huggingface.co/datasets/databricks/databricks-dolly-15k)
# 2. [Llama-2-7b-hf model](https://huggingface.co/meta-llama/Llama-2-7b-hf)
# 3. [Transformer Math 101 | EleutherAI Blog](https://blog.eleuther.ai/transformer-math)
# 4. [Hardware for LLMs](https://kaitchup.substack.com/p/hardware-for-llms)
# 5.
